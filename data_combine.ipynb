# %%
import pandas as pd
import numpy as np
import re

# %%
master = pd.read_csv('input/master.csv')
world_b = pd.read_csv('input/Data_Extract_From_Health_Nutrition_and_Population_Statistics/c6e927fe-a156-409e-8fac-fdc6053d8b92_Data.csv')

# %%
world_b.head()
# Out:
#                                          Series Name  Series Code  \
# 0  Adolescent fertility rate (births per 1,000 wo...  SP.ADO.TFRT
# 1  Adolescent fertility rate (births per 1,000 wo...  SP.ADO.TFRT
# 2  Adolescent fertility rate (births per 1,000 wo...  SP.ADO.TFRT
# 3  Adolescent fertility rate (births per 1,000 wo...  SP.ADO.TFRT
# 4  Adolescent fertility rate (births per 1,000 wo...  SP.ADO.TFRT
#
#      Country Name Country Code 2000 [YR2000] 2001 [YR2001] 2002 [YR2002]  \
# 0     Afghanistan          AFG       153.951       150.192       146.433
# 1         Albania          ALB       19.0372       18.9396        18.842
# 2         Algeria          DZA       11.7556       10.7178          9.68
# 3  American Samoa          ASM            ..            ..            ..
# 4         Andorra          AND            ..            ..            ..
#
#   2003 [YR2003] 2004 [YR2004] 2007 [YR2007] 2008 [YR2008] 2009 [YR2009]  \
# ...

# %%
world_b.shape
# Out:
# (4128, 19)

# %%
world_b.columns = [re.sub("[\(\[].*?[\)\]]",'', i) for i in world_b.columns]

# %%
world_b.columns
# Out:
# Index(['Series Name', 'Series Code', 'Country Name', 'Country Code', '2000 ',
#        '2001 ', '2002 ', '2003 ', '2004 ', '2007 ', '2008 ', '2009 ', '2010 ',
#        '2011 ', '2012 ', '2013 ', '2014 ', '2015 ', '2016 '],
#       dtype='object')

# %%
def clean_column(df):
    cols = df.columns
    new_column_names = []

    for col in cols:
        new_col = col.lstrip().rstrip().lower().replace (" ", "_") #strip beginning spaces, makes lowercase, add underscpre
        new_column_names.append(new_col)

    df.columns = new_column_names

# %%
clean_column(world_b)

# %%
world_b.columns
# Out:
# Index(['series_name', 'series_code', 'country_name', 'country_code', '2000',
#        '2001', '2002', '2003', '2004', '2007', '2008', '2009', '2010', '2011',
#        '2012', '2013', '2014', '2015', '2016'],
#       dtype='object')

# %%
master.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN      2,156,624,900
# 1               5.19  Albania1987           NaN      2,156,624,900
# 2               4.83  Albania1987           NaN      2,156,624,900
# 3               4.59  Albania1987           NaN      2,156,624,900
# 4               3.28  Albania1987           NaN      2,156,624,900
#
#    gdp_per_capita ($)       generation
# 0                 796     Generation X
# 1                 796           Silent
# 2                 796     Generation X
# ...

# %%
master.columns
# Out:
# Index(['country', 'year', 'sex', 'age', 'suicides_no', 'population',
#        'suicides/100k pop', 'country-year', 'HDI for year',
#        ' gdp_for_year ($) ', 'gdp_per_capita ($)', 'generation'],
#       dtype='object')

# %%
clean_column(master)

# %%
master.columns
# Out:
# Index(['country', 'year', 'sex', 'age', 'suicides_no', 'population',
#        'suicides/100k_pop', 'country-year', 'hdi_for_year', 'gdp_for_year_($)',
#        'gdp_per_capita_($)', 'generation'],
#       dtype='object')

# %%
master['gdp_for_year_($)'] = master.apply(lambda x: float(x['gdp_for_year_($)'].replace(',', '')), axis=1)

# %%
paises = [a for a in list(world_b.country_name.unique())if str(a) != "nan"]

# %%
paises
# Out:
# ['Afghanistan',
#  'Albania',
#  'Algeria',
#  'American Samoa',
#  'Andorra',
#  'Angola',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas, The',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'British Virgin Islands',
#  'Brunei Darussalam',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cabo Verde',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Cayman Islands',
#  'Central African Republic',
#  'Chad',
#  'Channel Islands',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Congo, Dem. Rep.',
#  'Congo, Rep.',
#  'Costa Rica',
#  "Cote d'Ivoire",
#  'Croatia',
#  'Cuba',
#  'Curacao',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Djibouti',
#  'Dominica',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt, Arab Rep.',
#  'El Salvador',
# ...

# %%
master = master[master['year'] >= 2000]
master = master[master['age'] == '15-24 years']

# %%
master.head()
# Out:
#      country  year     sex          age  suicides_no  population  \
# 136  Albania  2000  female  15-24 years            6      263900
# 137  Albania  2000    male  15-24 years            5      240000
# 148  Albania  2001    male  15-24 years           10      256039
# 149  Albania  2001  female  15-24 years            9      271359
# 160  Albania  2002    male  15-24 years           15      263067
#
#      suicides/100k_pop country-year  hdi_for_year  gdp_for_year_($)  \
# 136               2.27  Albania2000         0.656      3.632044e+09
# 137               2.08  Albania2000         0.656      3.632044e+09
# 148               3.91  Albania2001           NaN      4.060759e+09
# 149               3.32  Albania2001           NaN      4.060759e+09
# 160               5.70  Albania2002           NaN      4.435079e+09
#
#      gdp_per_capita_($)    generation
# 136                1299  Generation X
# 137                1299  Generation X
# 148                1451    Millenials
# ...

# %%
master.shape
# Out:
# (2700, 12)

# %%
data2 = world_b[world_b["country_name"]== "Albania"]
data2.head()
# Out:
#                                            series_name        series_code  \
# 1    Adolescent fertility rate (births per 1,000 wo...        SP.ADO.TFRT
# 218                      Age at first marriage, female     SP.DYN.SMAM.FE
# 435                        Age at first marriage, male     SP.DYN.SMAM.MA
# 652  Births attended by skilled health staff (% of ...     SH.STA.BRTC.ZS
# 869              Capital health expenditure (% of GDP)  SH.XPD.KHEX.GD.ZS
#
#     country_name country_code                 2000                 2001  \
# 1        Albania          ALB              19.0372              18.9396
# 218      Albania          ALB                 23.9                 23.3
# 435      Albania          ALB                 28.5                 27.3
# 652      Albania          ALB                 99.1                   99
# 869      Albania          ALB  0.00518756023666356  0.00692165558575653
#
#                     2002                2003               2004  \
# ...

# %%
paises[1]
# Out:
# 'Albania'

# %%
columnas = [a for a in list(world_b.columns) if a not in ['series_name','series_code',
 'country_name',
 'country_code',]]
columnas
# Out:
# ['2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016']

# %%
¿Qué tiene que hacer Fer ahora?
 dists[(np.where((dists >= r) & (dists <= r + dr)))]
# Out:
#   File "<ipython-input-21-20e307d96979>", line 2
#     dists[(np.where((dists >= r) & (dists <= r + dr)))]
#     ^
# IndentationError: unexpected indent

# %%
master.shape
# Out:
# (2700, 12)

# %%
a = master.iloc[0]["country"], master.iloc[0]['year']
type(a)
# Out:
# tuple

# %%
master["prueba"] = 0

# %%
master.head()
# Out:
#      country  year     sex          age  suicides_no  population  \
# 136  Albania  2000  female  15-24 years            6      263900
# 137  Albania  2000    male  15-24 years            5      240000
# 148  Albania  2001    male  15-24 years           10      256039
# 149  Albania  2001  female  15-24 years            9      271359
# 160  Albania  2002    male  15-24 years           15      263067
#
#      suicides/100k_pop country-year  hdi_for_year  gdp_for_year_($)  \
# 136               2.27  Albania2000         0.656      3.632044e+09
# 137               2.08  Albania2000         0.656      3.632044e+09
# 148               3.91  Albania2001           NaN      4.060759e+09
# 149               3.32  Albania2001           NaN      4.060759e+09
# 160               5.70  Albania2002           NaN      4.435079e+09
#
#      gdp_per_capita_($)    generation  prueba
# 136                1299  Generation X       0
# 137                1299  Generation X       0
# ...

# %%
world_b['series_name'].value_counts()
# Out:
# Maternal mortality ratio (modeled estimate, per 100,000 live births)              217
# Literacy rate, adult male (% of males ages 15 and above)                          217
# Domestic general government health expenditure per capita (current US$)           217
# Adolescent fertility rate (births per 1,000 women ages 15-19)                     217
# School enrollment, secondary, male (% net)                                        217
# External health expenditure per capita (current US$)                              217
# Lifetime risk of maternal death (%)                                               217
# Domestic private health expenditure per capita, PPP  (current international $)    217
# Public spending on education, total (% of GDP)                                    217
# Births attended by skilled health staff (% of total)                              217
# Capital health expenditure (% of GDP)                                             217
# ...

# %%
cap_exp = world_b[world_b['series_name']=='Capital health expenditure (% of GDP)'].reset_index()
cap_exp
# Out:
#      index                            series_name        series_code  \
# 0      868  Capital health expenditure (% of GDP)  SH.XPD.KHEX.GD.ZS
# 1      869  Capital health expenditure (% of GDP)  SH.XPD.KHEX.GD.ZS
# 2      870  Capital health expenditure (% of GDP)  SH.XPD.KHEX.GD.ZS
# 3      871  Capital health expenditure (% of GDP)  SH.XPD.KHEX.GD.ZS
# 4      872  Capital health expenditure (% of GDP)  SH.XPD.KHEX.GD.ZS
# ..     ...                                    ...                ...
# 212   1080  Capital health expenditure (% of GDP)  SH.XPD.KHEX.GD.ZS
# 213   1081  Capital health expenditure (% of GDP)  SH.XPD.KHEX.GD.ZS
# 214   1082  Capital health expenditure (% of GDP)  SH.XPD.KHEX.GD.ZS
# 215   1083  Capital health expenditure (% of GDP)  SH.XPD.KHEX.GD.ZS
# 216   1084  Capital health expenditure (% of GDP)  SH.XPD.KHEX.GD.ZS
#
#               country_name country_code                 2000  \
# 0              Afghanistan          AFG                   ..
# ...

# %% [markdown]
# ### Entendiendo la funcionzaca
#
# data = de cada lista de países saca un dataframe y resetea el index
# Iteramos por los años de la lista de años del dataset world_b para sacar el dato de la FILA 0 del dataframe anterior y el año.
# Guarda el dato en una variable -- eldatito

# %%
def lafuncionzaca(data1,data2,listapaises,listacolumnas):
    lista = []
    for pais in listapaises:
        data = data1[(data1["country_name"]== pais)]
        data.reset_index
        for year in listacolumnas:
            eldatito = data1.at[0,str(year)]
            for i in range(0,len(data2)):
                a = data2.iloc[i]["country"], data2.iloc[i]['year']
                if a == (pais,year):
                    lista.append(eldatito)
                    #data2.iloc[i]["prueba"] = eldatito
                else:
                    #data2.iloc[i]["prueba"] = 0
                    lista.append(0)
    return lista

# %%
lista = lafuncionzaca(cap_exp,master,paises,columnas)

# %%
set(lista)
# Out:
# {0}

# %%
master.head()
# Out:
#      country  year     sex          age  suicides_no  population  \
# 136  Albania  2000  female  15-24 years            6      263900
# 137  Albania  2000    male  15-24 years            5      240000
# 148  Albania  2001    male  15-24 years           10      256039
# 149  Albania  2001  female  15-24 years            9      271359
# 160  Albania  2002    male  15-24 years           15      263067
#
#      suicides/100k_pop country-year  hdi_for_year  gdp_for_year_($)  \
# 136               2.27  Albania2000         0.656      3.632044e+09
# 137               2.08  Albania2000         0.656      3.632044e+09
# 148               3.91  Albania2001           NaN      4.060759e+09
# 149               3.32  Albania2001           NaN      4.060759e+09
# 160               5.70  Albania2002           NaN      4.435079e+09
#
#      gdp_per_capita_($)    generation  prueba
# 136                1299  Generation X       0
# 137                1299  Generation X       0
# ...

# %%
for pais in paises:
    data = world_b[world_b["country_name"]== pais]
    data.reset_index
    for year in columnas:
        eldatito = world_b.at[0,str(year)]
        for i in range(0,len(master)):
            a = master.iloc[i]["country"], master.iloc[i]['year']

# %%
a

# %%
master.info()

# %%
master.head()

# %%
master.head()

# %%
data = world_b[(world_b["country_name"]== str(paises[2]))]
data.head()

# %%
#lista de países
for país in lista de países: 
    
    for año en años 
        ya puedo hacer el .at(0,año)
        creo que así :) 

            voy a buscar en la docu para sacar el índice :) :rocket:
                        y ahora seguimos

# %%
da.head()

# %%
da.head()

# %%
da = world_b

# %%
da.set_index("country_name")

# %%
hola =world_b.at[2,'2000']
print(hola)

# %%
#for i in range(1, len(master)):
    #master.loc[i,'Adolescent fertility rate (births per 1,000 women ages 15-19)'] = world_b.at[, '2000']

for i in range(1, len(master)):
   if master.loc[i,'country']==world_b.loc[i,'country_name']:
       master.append(world_b.at[i,'2000'])
#master.loc[master['country']==world_b['country_name'], world_b['2000']]

# %%
world_b['series_name'][0]

# %%
master.head()

# %%
master.loc['country']
